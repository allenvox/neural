# %% [markdown]
# Import PyTorch, its utils & datasets info from torchvision

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %% [markdown]
# Create a transform to normalize dataset to values of {-1;1}, where -1 is a black pixel, 1 - a white pixel

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# %% [markdown]
# Download MNIST dataset

# %%
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# %% [markdown]
# Configure DataLoader to load a shuffled batch of 64 images

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# Simple forward-propagation neural network

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(28 * 28, 128) # input neurons layer: 28x28 pxs input, 128 neurons output
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)      # hidden layers: 128 & 64 neurons
        self.fc3 = nn.Linear(64,10)        # output layer: 10 digits (0-9)

    def forward(self, x):
        x = self.flatten(x) # 2D image -> 1D vector
        x = self.fc1(x)     # linear layer (fully connected)
        x = self.relu(x)    # activation function
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)     # prediction
        return x

# %% [markdown]
# Initialize NN-model on a certain device (CPU / GPU)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SimpleNN().to(device)

# %% [markdown]
# Get one batch of data, where images is an array of input pixels matrices, labels - an array of its true digit

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)
images, labels = images.to(device), labels.to(device)

# %% [markdown]
# Forward pass

# %%
outputs = model(images)

# %% [markdown]
# Output

# %%
print("Outputs:", outputs.shape) # [batch_size, 10]
print("One batch predictions:", outputs)
# print("Prediction for outputs[0]:", outputs[1])
# Out:
# Outputs: torch.Size([64, 10])
# One batch predictions: tensor([[-1.9244e-01,  4.0793e-02, -1.5000e-01, -2.1233e-01, -3.5274e-01,
#           2.5505e-01, -1.6202e-02,  2.2252e-01, -2.0773e-02,  9.2730e-02],
#         [-2.0227e-01, -4.5271e-02, -7.8339e-02, -1.7497e-01, -3.7126e-01,
#           2.5647e-01, -3.7150e-02,  2.5736e-01,  8.9434e-02,  1.3967e-01],
#         [-1.3223e-01,  2.2947e-03, -9.5333e-02, -7.8210e-02, -3.3718e-01,
#           3.2697e-01, -7.8083e-02,  3.1189e-01,  3.0813e-02,  7.5548e-02],
#         [-1.2880e-01, -1.5267e-02, -8.0585e-02, -1.6228e-01, -3.0396e-01,
#           2.5730e-01, -9.9179e-02,  2.3158e-01,  1.1273e-01,  1.8828e-01],
#         [-1.2360e-01,  3.4693e-02, -4.1439e-02, -2.0641e-01, -3.4783e-01,
#           2.7297e-01, -7.3205e-02,  1.5680e-01,  1.3281e-01,  1.0054e-01],
#         [-4.6114e-02,  5.5228e-02, -1.3950e-01, -1.8935e-01, -2.9057e-01,
#           2.3979e-01, -3.2285e-04,  1.9786e-01, -2.9998e-02,  1.5677e-01],
#         [-1.9793e-01,  1.4070e-02, -9.7672e-02, -1.9859e-01, -3.4375e-01,
#           1.8993e-01, -9.1685e-02,  1.6726e-01,  1.0386e-01,  1.2422e-01],
#         [-1.8630e-01, -2.4222e-02, -1.0686e-01, -2.6906e-01, -3.0059e-01,
#           2.9449e-01, -1.2090e-01,  1.9676e-01, -4.1435e-02,  7.5775e-02],
#         [-1.1501e-01,  9.0401e-02, -2.1230e-01, -1.2689e-01, -3.7290e-01,
#           2.6570e-01,  2.3363e-02,  2.2006e-01, -5.4465e-03,  1.3109e-01],
#         [-1.7387e-01,  6.4866e-02, -3.3779e-02, -1.9084e-01, -3.0392e-01,
#           2.4304e-01, -2.2748e-02,  1.5353e-01,  2.0231e-01,  1.5323e-01],
#         [-1.9009e-01,  7.9635e-02, -6.5184e-02, -1.4074e-01, -3.5578e-01,
#           2.5503e-01, -1.2418e-01,  2.2483e-01,  1.4307e-01,  1.4153e-01],
#         [-1.7198e-01,  4.5509e-02, -6.4896e-02, -2.0465e-01, -2.7477e-01,
#           2.0770e-01, -6.2254e-02,  1.5186e-01,  1.3793e-01,  8.5226e-02],
#         [-9.8896e-02, -1.4442e-02, -4.1289e-02, -1.7045e-01, -3.4233e-01,
#           2.5804e-01,  1.1246e-02,  1.7177e-01,  1.0866e-01,  1.1239e-01],
#         [-9.6006e-02,  1.2090e-01, -5.6113e-02, -1.1916e-01, -2.9185e-01,
#           2.5690e-01, -3.5844e-02,  1.4757e-01,  1.1449e-01,  1.4313e-01],
#         [-6.7173e-02,  3.3337e-02, -1.9841e-01, -2.1891e-01, -3.5200e-01,
#           2.4264e-01,  1.0036e-01,  2.8351e-01, -1.1624e-01,  1.1863e-01],
#         [-1.1323e-01,  4.7534e-02,  3.0533e-02, -1.2810e-01, -2.6355e-01,
#           3.1408e-01, -8.9866e-02,  2.1338e-01,  1.5536e-01,  1.5489e-01],
#         [-2.0683e-01, -8.9403e-03,  8.5192e-02, -1.5602e-01, -1.7452e-01,
#           2.0217e-01, -1.2713e-01,  1.5615e-01,  1.5626e-01,  1.6340e-01],
#         [-8.5003e-02,  6.7412e-02, -6.8054e-02, -2.3779e-01, -3.2970e-01,
#           2.5599e-01, -4.9728e-02,  1.3594e-01,  8.1717e-02,  1.6298e-01],
#         [-1.3170e-01, -5.4886e-02, -2.3408e-01, -1.5364e-01, -3.4278e-01,
#           1.8758e-01,  3.5932e-02,  3.0278e-01, -8.2870e-02,  1.5476e-01],
#         [-1.7977e-01,  8.3292e-03, -1.0030e-01, -1.4700e-01, -3.1139e-01,
#           2.3201e-01, -8.6981e-02,  1.1154e-01,  2.2138e-02,  8.9124e-02],
#         [-2.3304e-01, -1.4072e-02, -5.2859e-02, -2.1386e-01, -3.4838e-01,
#           2.0701e-01, -7.9172e-02,  2.0567e-01,  1.5247e-01,  1.0659e-01],
#         [-1.3000e-01,  1.1604e-02, -6.4513e-02, -1.7939e-01, -3.3171e-01,
#           2.6772e-01, -2.4839e-02,  2.4315e-01,  7.3169e-02,  1.3490e-01],
#         [-6.6908e-02,  9.6325e-02, -2.3315e-02, -1.2868e-01, -2.2883e-01,
#           2.7786e-01, -2.8566e-02,  2.1524e-01,  1.9355e-01,  2.0329e-01],
#         [-1.1740e-01,  2.2126e-02, -4.0266e-02, -1.9306e-01, -3.0567e-01,
#           2.4386e-01, -6.1548e-02,  1.7063e-01,  1.4108e-01,  2.0449e-01],
#         [-9.9187e-02,  6.7279e-02, -2.4973e-02, -1.4229e-01, -2.7347e-01,
#           2.6590e-01, -3.1228e-02,  2.2454e-01,  1.7426e-01,  1.5666e-01],
#         [-4.9142e-02,  7.6725e-02, -7.2151e-02, -2.1860e-01, -3.0137e-01,
#           2.3145e-01, -3.8750e-02,  2.0799e-01,  1.5528e-01,  2.1748e-01],
#         [-1.9603e-01,  4.3774e-02, -1.0362e-01, -1.8165e-01, -3.6078e-01,
#           1.9790e-01, -6.7630e-02,  1.7893e-01,  7.9111e-02,  1.3387e-01],
#         [-1.1074e-01,  1.6255e-02, -1.1772e-01, -1.6476e-01, -3.5479e-01,
#           2.4548e-01,  4.1220e-02,  2.2706e-01,  8.1062e-02,  1.9063e-01],
#         [-7.0685e-02,  2.7054e-02, -1.2162e-01, -1.6313e-01, -2.4493e-01,
#           2.4754e-01,  3.7446e-02,  2.0975e-01,  1.0884e-01,  1.3910e-01],
#         [-8.1006e-02,  1.0721e-01, -2.1140e-01, -2.6837e-01, -2.7391e-01,
#           2.9305e-01,  7.2317e-02,  2.3965e-01, -9.0165e-02,  2.0298e-01],
#         [-1.1514e-01,  6.6815e-02, -2.2775e-02, -8.7694e-02, -2.4973e-01,
#           2.7315e-01,  3.0899e-02,  1.9869e-01,  1.0634e-01,  1.2317e-01],
#         [-2.1652e-01,  7.2765e-03, -6.3587e-02, -1.6453e-01, -3.0008e-01,
#           1.9870e-01, -6.0237e-02,  1.0572e-01,  4.9874e-02,  7.7449e-02],
#         [-2.0320e-01,  2.1343e-02, -5.2400e-02, -1.8769e-01, -3.3490e-01,
#           2.3982e-01, -1.8667e-02,  1.7408e-01,  1.1158e-01,  1.1971e-01],
#         [-1.1090e-01, -4.8885e-03, -7.9052e-02, -1.5968e-01, -2.1178e-01,
#           2.8476e-01, -4.9963e-02,  1.3315e-01,  9.0563e-02,  1.3132e-01],
#         [-1.5187e-01, -7.4179e-02, -2.6209e-01, -2.1088e-01, -3.9298e-01,
#           2.4096e-01, -7.3955e-03,  2.5619e-01, -3.5036e-02,  1.1608e-01],
#         [-1.9445e-01,  5.3302e-02, -1.5823e-01, -2.0420e-01, -4.5311e-01,
#           2.2393e-01, -2.3046e-02,  1.6565e-01,  1.6354e-01,  1.3317e-01],
#         [-1.8900e-01,  8.3407e-02, -6.4518e-02, -1.9910e-01, -3.8933e-01,
#           2.8691e-01, -7.2902e-02,  1.8258e-01,  1.8825e-01,  1.6941e-01],
#         [-1.7648e-01,  2.8344e-02, -1.2830e-01, -1.3699e-01, -3.6919e-01,
#           2.4363e-01, -4.2182e-02,  2.3346e-01,  1.2014e-01,  1.5842e-01],
#         [-1.4689e-01,  5.3384e-02, -1.5729e-01, -1.7047e-01, -3.3741e-01,
#           2.1852e-01, -1.7390e-02,  1.9331e-01, -3.5922e-02,  1.8449e-01],
#         [-2.3953e-01,  2.9044e-03, -7.1311e-02, -1.9322e-01, -2.4342e-01,
#           1.6985e-01, -1.6746e-02,  2.1008e-01,  5.6937e-02,  1.1203e-01],
#         [-1.5033e-01, -4.6450e-03, -9.8336e-02, -1.4441e-01, -2.3809e-01,
#           2.3996e-01, -2.8035e-02,  2.8541e-01, -3.9676e-02,  1.3619e-01],
#         [-6.8765e-02,  5.7223e-03, -4.8877e-02, -1.1672e-01, -2.7010e-01,
#           2.8240e-01, -2.7063e-02,  2.5957e-01,  9.1328e-02,  6.4537e-02],
#         [-1.1113e-01,  9.1160e-02, -2.6492e-02, -2.4148e-01, -2.8257e-01,
#           2.0664e-01, -2.6352e-02,  1.4785e-01,  1.1001e-01,  1.6598e-01],
#         [-1.0659e-01,  8.9969e-03, -9.5211e-02, -1.3430e-01, -1.7357e-01,
#           2.5090e-01, -7.6088e-02,  1.3111e-01,  2.1064e-02,  9.2629e-02],
#         [-1.5476e-01, -3.9396e-02, -7.5237e-02, -2.0956e-01, -2.7299e-01,
#           2.4129e-01, -6.9498e-02,  1.8487e-01,  6.6387e-02,  1.0874e-01],
#         [-1.5363e-01, -3.5215e-02,  7.3804e-02, -1.3634e-01, -2.7432e-01,
#           2.4141e-01, -6.5184e-02,  1.7639e-01,  1.7078e-01,  1.3178e-01],
#         [-1.3598e-01,  1.5130e-01, -4.3164e-02, -1.8807e-01, -2.9936e-01,
#           2.0827e-01, -6.6694e-02,  2.1150e-01,  1.0706e-01,  9.6603e-02],
#         [-7.8144e-02,  9.0995e-03, -1.2688e-01, -1.4332e-01, -3.2750e-01,
#           2.6323e-01, -7.5508e-02,  2.5662e-01,  4.7483e-02,  1.6158e-01],
#         [-1.5958e-01, -1.2958e-02, -7.9032e-04, -1.8655e-01, -2.9418e-01,
#           2.9229e-01, -7.0160e-02,  1.1690e-01,  1.6761e-01,  1.5473e-01],
#         [-1.8723e-01, -6.1683e-02, -2.1616e-02, -1.1805e-01, -2.1793e-01,
#           2.4515e-01,  6.9385e-03,  1.9504e-01,  1.3873e-01,  5.4996e-02],
#         [-1.2419e-01,  1.2507e-02, -2.4190e-01, -1.4654e-01, -3.0415e-01,
#           2.5839e-01, -3.1722e-02,  2.7079e-01, -4.4174e-02,  1.6040e-01],
#         [-1.3081e-01, -1.2011e-02, -4.7245e-02, -1.2235e-01, -2.9391e-01,
#           2.1780e-01, -8.6900e-02,  1.8842e-01,  5.3083e-02,  9.8130e-02],
#         [-1.9755e-01,  4.1800e-02, -2.6842e-02, -1.1713e-01, -3.5046e-01,
#           2.4752e-01, -4.7491e-02,  1.9425e-01,  1.8780e-01,  1.3756e-01],
#         [-1.4619e-01, -6.2782e-03, -7.2151e-02, -2.0004e-01, -2.4229e-01,
#           3.2944e-01, -9.9152e-02,  2.1059e-01, -2.0077e-02,  7.6475e-02],
#         [-9.1420e-02,  3.7025e-02, -3.3726e-02, -1.6384e-01, -2.7924e-01,
#           2.5131e-01, -5.5160e-02,  1.4957e-01,  1.5451e-01,  1.4155e-01],
#         [-2.1898e-01,  1.8348e-03, -5.0853e-02, -2.1051e-01, -3.8457e-01,
#           2.6293e-01, -1.2535e-01,  1.9945e-01,  1.6554e-01,  1.4959e-01],
#         [-5.4288e-02,  9.2431e-02, -1.1529e-01, -1.2405e-01, -2.4425e-01,
#           2.9479e-01,  1.4829e-02,  2.3662e-01,  1.8468e-02,  8.1282e-02],
#         [-9.6115e-02,  3.2366e-02, -8.0165e-03, -2.1376e-01, -3.0117e-01,
#           2.1570e-01, -6.8731e-02,  2.0555e-01,  8.9992e-02,  1.1464e-01],
#         [-6.5415e-02,  2.6105e-02, -2.2126e-01, -2.1770e-01, -3.4153e-01,
#           2.8586e-01,  4.0104e-02,  2.7395e-01, -1.4856e-01,  1.5867e-01],
#         [-1.2335e-01,  7.3769e-02, -1.1463e-01, -1.3950e-01, -3.7779e-01,
#           2.4971e-01,  8.3660e-03,  2.1723e-01,  1.3194e-01,  1.2031e-01],
#         [-1.1137e-01,  9.5500e-03, -2.3851e-01, -2.4471e-01, -3.7117e-01,
#           2.4489e-01,  9.4691e-02,  2.7313e-01, -1.5638e-01,  1.2212e-01],
#         [-5.4334e-02,  2.8679e-02, -1.8036e-01, -1.3747e-01, -3.3875e-01,
#           2.6144e-01,  3.1024e-02,  2.6981e-01, -2.9408e-02,  6.9661e-02],
#         [-2.3763e-01, -3.1995e-02, -3.5728e-02, -1.7091e-01, -2.5316e-01,
#           2.1363e-01, -6.7100e-02,  1.6907e-01,  1.4466e-01,  1.0248e-01],
#         [-2.0270e-01,  8.0608e-02, -4.1265e-02, -1.9800e-01, -3.1076e-01,
#           2.8581e-01, -4.5855e-02,  1.6865e-01,  1.5657e-01,  1.3599e-01]],
#        grad_fn=<AddmmBackward0>)
